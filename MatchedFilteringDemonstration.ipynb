# %% [markdown]
# #Introduction## What are we doing?We're doing a little interactive project to give you a better feel for how LIGO data analysis actually works.  In particular, we'll be doing **matched filtering** of some data.You can kind of think of LIGO as a really sensitive microphone, and the data that comes out is like a sound recording.  (Except, of course, that sound requires air to travel through, while gravitational waves travel through spacetime itself.)  In fact, if you go to the LIGO control room, they'll often play the data over speakers, because this is a really useful way of thinking about it.  It even happens to be in the right range for human hearing.So, we'll be using the sound cards in these computers and some attached microphones as if they were LIGO detectors.  First, we'll measure the noise in the detector to get a feel for the basics &mdash; and because that's a crucial first step for real data analysis.  Then, we'll create a really simple signal, put it into our data, and see if we can detect it with matched filtering.  That's kind of cheating, but it's good practice for seeing how the method works.  Finally, we'll try to do the real thing: record an actual signal, and compare it to pre-recorded templates to make a detection.## What am I looking at?This is a python notebook.  It's connected to an actual python session, but it runs through a web browser,so we can format things nicely and give some explanations, and so you don't have to copy-and-paste all the instructions into a normal python session.  (It's meant to look and work like Mathematica, if you've ever used that before.)Each of the sections in gray with something like "`In[1]:`" in front of it is called a *cell* and contains code for you to run.  Run the code by placing your cursor in the cell, then pressing Shift+Enter.  First, we change to the correct directory:

# %%
cd ~/Research/Talks/REU2012/
# Out:
# /Users/boyle/Research/Talks/REU2012

# %% [markdown]
# Next, we'll load a few necessary packages that set up python to run the rest of our code:

# %%
import MatchedFiltering  # This is the main custom module for matched filteringimport time  # This just lets us wait 2 seconds before recordingmpl.rcParams['figure.figsize'] = 9,5  # Set default figure size (in inches)SamplingFrequency = 44100  # Recording sampling rate (in Hertz)

# %% [markdown]
# You won't be expected to understand the python code at all, but you should run it, follow along with the explanations, and try to understand all the graphs.

# %% [markdown]
# <br /><br /><br /># Characterizing noise in the detectorYou need to understand the noise in your detector when there are no signals, to know for sure if you've actually measured a signal or just noise that happens to look like a signal.## Measure the background noise level

# %% [markdown]
# Every sound card has different noise, and the noise a particular sound card measures at a particular time can change if there are fans running in the room, an air conditioner running, different lights on... whatever.  So we have to measure the background noise before we can do anything else.To do that, we'll just record silence.  Evaluate the following cell (Shift+Enter) and be very quiet until it's done (12 seconds).

# %%
time.sleep(2) # wait 2 seconds before starting to record, to let things get quiet...Noise = MatchedFiltering.RecordWaveform(10, SamplingFrequency) # Record for 10 seconds
# Out:
# Recording...Done recording.

# %% [markdown]
# Now python has an object named `Noise`, which contains the data from our recording of the background noise.If you want to listen to it, you can evaluate the following cell.  Be careful; this might be loud!

# %%
Noise.Play()

# %% [markdown]
# Do you hear any weird features in your noise data?  If you hear any loud sudden noises, you might have to record the background noise again.Do you hear any buzzing or whining?  If so, that should be fine, but look to see if they show up in the next step.

# %%
LIGONoise = MatchedFiltering.Waveform('Sounds/LIGONoise.wav')

# %%
### Convert to frequency domainLIGONoiseFFT = LIGONoise.dt * np.fft.fft(LIGONoise.data) # Take the Fourier transform and save as 'NoiseFFT'LIGONoiseFrequencies = np.fft.fftfreq(LIGONoise.N, LIGONoise.dt) # Values of the f_i### Only plot some of the data, because python is slow at this jobPlotPoints = LIGONoise.N/2 # first half of the data (positive frequencies)#PlotEvery = 50 # every 500th point for speed### Now do the actual plotting:figure()loglog(LIGONoiseFrequencies[:PlotPoints:PlotEvery], abs(LIGONoiseFFT[:PlotPoints:PlotEvery]));#xlim(0,25000);xlim(10,1000);xlabel("$f_i$ (measured in Hertz)");ylabel("$\\tilde{n}_{f_i}$ (measured in arbitrary units)");title("Amplitude of the Fourier transform of Noise");

# %% [markdown]
# ## Convert noise to the frequency domain

# %% [markdown]
# Now, we can think of our noise as a function of time: $n(t)$.  You may be familiar with the Fourier transform, which lets us write $n(t)$ as a sum of sines of different sizes, with all the frequencies thatcould be in the data:$$n(t) = \sum_{f_i} \left[ \tilde{n}_{f_i} \sin(2\pi f_i t + \phi_{f_i}) \right]~.$$The sum goes over all frequencies $f_i$ that could be in the data, $\tilde{n}_{f_i}$ are the numbers telling us how much of that particular frequency is in our data (the amplitude), and $\phi_{f_i}$ are the numbers telling us just when that frequency hits its peak.  (For now, we'll ignore $\phi_{f_i}$ to keep things simpler.)  So, for example, if we record a sound that has a frequency of 440 Hz, then $\tilde n_{\text{440 Hz}}$ will be really big compared to all the other $\tilde{n}_{f_i}$.This conversion of $n(t)$ to $\tilde{n}_{f_i}$ and $\phi_{f_i}$ is called the "Fourier transform". You'll definitely see this again someday.  There's also a very quick way of computing it called the "*fast* Fourier transform" (fft), which you might see again some day.  In the next cell, we calculate the fft of the noise you recorded above, and plot the amplitudes on a logarithmic scale.

# %%
### Convert to frequency domainNoiseFFT = Noise.dt * np.fft.fft(Noise.data) # Take the Fourier transform and save as 'NoiseFFT'NoiseFrequencies = np.fft.fftfreq(Noise.N, Noise.dt) # Values of the f_i### Only plot some of the data, because python is slow at this jobPlotPoints = Noise.N/2 # first half of the data (positive frequencies)##PlotEvery = 500 # every 500th point for speedPlotEvery = 50### Now plot it:figure()semilogy(NoiseFrequencies[:PlotPoints:PlotEvery], abs(NoiseFFT[:PlotPoints:PlotEvery]));#xlim(0,25000);xlim(0,5000);xlabel("$f_i$ (measured in Hertz)");ylabel("$\\tilde{n}_{f_i}$ (measured in arbitrary units)");title("Amplitude of the Fourier transform of Noise");

# %% [markdown]
# Your line probably jumps around a bit, with lots of spikes up and down, but generallydecreasing with higher frequencies.  This means that there's a lot of noise at low frequencies (bass), and less at high frequencies (treble).(The curve stops at about 24,000 Hz because that's the highest frequency we recorded.  It also happensto be a little higher than the highest frequency humans can hear, so your microphone probably isn't even designed to be sensitive to higher frequencies.)

# %% [markdown]
# ## Questions* Did you hear anything funny in your noise recording?  Was there any buzzing or humming?  Where did these come from?* If there was any buzzing or humming, can you see anything in the Fourier transform that might correspond to that sound?* Can you explain any other features of your fft plot?* Do you feel comfortable with Fourier transforms?  If not, you might want to open the other notebook "FourierTransforms" in this directory.* LIGO doesn't control gravitational waves.  We can never turn them all off, so we can never be sure if we're looking at pure noise, or if there's some signal in there.  How could we know what is really just noise, and what isn't?

# %% [markdown]
# <br /><br /><br /># Create a simple signal, inject it, and extract itHere's where we'll make up a signal that's kind of vaguely like a real gravitational-wave signal, but is really easy to calculate.  Then, we'll add it to our noise data &mdash; but so quietly that we can't hear it.Finally, we'll detect it again with matched filtering.## Make up a "swept sine-Gaussian" signalThis will be a signal with gradually increasing (sweeping) frequency, but whose amplitude is a Gaussian function.

# %%
### Parameters of our signalSineGaussianCenter = 5.0 # Center of the function in secondsSineGaussianFWHM = 2.9 # full-width at half-max (FWHM) of the Gaussian in secondsSineGaussianFreq = 50 # Frequency of the sine in HertzSineSweep = SineGaussianFreq/6.0 # Amount of frequency sweep from one side of Gaussian to the other### Define the functionsigma = SineGaussianFWHM / (2*sqrt(2*log(2)))def SweptSineGaussianFunction(t) :    return exp(-(t-SineGaussianCenter)**2/(2*sigma**2)) \        * cos(2*pi*(SineGaussianFreq+SineSweep*(t-SineGaussianCenter)/SineGaussianFWHM)              *(t-SineGaussianCenter))### Evaluate the function and save the dataSweptSineGaussian = MatchedFiltering.Waveform(Noise)SweptSineGaussian.data = SweptSineGaussianFunction(Noise.Time())### Now plot it as a function of timefigure()plot(SweptSineGaussian.Time(), SweptSineGaussian.data, lw=0.4);gcf().set_size_inches(9,5);xlabel("$t$ (seconds)");ylabel("Amplitude (arbitrary units)");title("Swept sine-Gaussian signal in the time domain");

# %% [markdown]
# It might be hard to see all the individual oscillations above, but if you zoom in, you can see that they're there, and they get closer together later in time (the frequency gets higher).If you want, you can listen to the signal we just created:

# %%
SweptSineGaussian.Play()

# %% [markdown]
# It's also interesting to look at this signal in the frequency domain, so let's plot the Fourier transform:

# %%
### Evaluate the fftSweptSineGaussianFFT = SweptSineGaussian.dt * np.fft.fft(SweptSineGaussian.data)### Plot it, as abovefigure()semilogy(NoiseFrequencies[:PlotPoints], abs(SweptSineGaussianFFT[:PlotPoints]));xlim(0,SineGaussianFreq*5)xlabel("$f_i$ (measured in Hertz)");ylabel("$a_{f_i}$ (measured in arbitrary units)");title("Amplitude of the Fourier transform of the swept sine-Gaussian");

# %% [markdown]
# (Notice that we've zoomed in on the low frequencies, because that's where stuff is happening.  Off to the right, the graph just gets flatter and more boring.  If you want to see for yourself, zoom out by changing the numbers in `xlim`.)The main feature to note here is that the peak amplitude is at 80 Hz, which is what we set 'SineGaussianFreq' to above.  If the frequency were constant, we'd have a narrow spike there.  But we'vealso made the frequency sweep, which makes the spike a lot broader.  There's really a mix of frequencies inthe data.So that's our signal, as both a function of time and frequency.

# %% [markdown]
# ## Inject the signal into our noise (make up fake detector data)For our signal, we'll use the swept sine-Gaussian we made above, but shift it by 1 second just to makethings a little difficult.

# %%
SignalOffset = 1.0 # Time to shift the signal (in seconds)Signal = MatchedFiltering.Waveform(SweptSineGaussian) # Make a copy of the swept sine-GaussianSignal.data = SweptSineGaussianFunction(SweptSineGaussian.Time()+SignalOffset) # Shift the time

# %% [markdown]
# Now we'll add this signal to the noise to make up fake detector data.  But just to make things moreinteresting, we'll make the signal tiny compared to the noise &mdash; about ten thousand times smaller!

# %%
InputSignalToNoiseRatio = 1./100. # ...roughlyDetectorData = (1-InputSignalToNoiseRatio)*Noise + InputSignalToNoiseRatio*SweptSineGaussian

# %% [markdown]
# Now, just to see that the signal really is tiny compared to the noise, listen to our detector data.  (Again,be careful because this might be loud.)

# %%
DetectorData.Play()

# %% [markdown]
# You shouldn't be able to hear the signal at all.  Not even close &mdash; the data is practically the same as the noise.  So that will make it all the more impressive when we can easily pull the signal out of the data using matched filtering.

# %% [markdown]
# ## Matched filtering explainedBecause our signal is so tiny compared to our noise, we can't just look at the data to see if the signal isin there.  Instead, we have to test if the signal $s$ is in the data $d$.  To do this, we measure the **match** between $d$ and $s$, which is defined roughly as$$ M(d, s) \propto \sum_{f_i} \frac{\tilde{d}_{f_i} \tilde{s}_{f_i} \cos \delta\phi_{f_i}}{\tilde{n}_{f_i}^2} $$This formula is really important, so let's try to understand each piece of it.Here, $\delta \phi_{f_i}$ is the difference in the phases $\phi_{f_i}$ of the Fourier transforms of $d$ and $s$.  If $d$ and $s$ are "in phase" for this frequency, $\delta\phi_{f_i}$ will be small, so the cosinewill be roughly 1, and this term will add to the total match.  If $d$ and $s$ are "out of phase", the cosinewill be roughly -1, and this term will make the match smaller.We also have $\tilde{n}_{f_i}$, which is the Fourier-transform amplitude of the noise in the detector, which we've measured previously.  If there's a lot of noise in the detector at a particular frequency, then the data $\tilde{d}_{f_i}$ will be large, but garbage &mdash; so we want to ignore it.  And the louder the noise, the more we want to ignore that frequency.  Dividing each term of the sum by the noise (squared) doesthis automatically for us.  We might think of this like the controls on a stereo.  If the bass is reallyloud and noisy, we might turn it down so we can hear the other parts.After adding up all the terms in the sum, if the match is big, we might say that the signal $s$ is probably in the data $d$.  And if the match is small, we probably didn't detect the signal.  In fact, if the data andthe signal are a perfect match, then$$\text{Match}(d,s) = \frac{M(d,s)} {\sqrt{M(d,d) M(s,s)}} $$will be 1.  So this is the quantity we're most interested in.Once you've read this far, take the time to ask any questions and discuss this concept.

# %% [markdown]
# ## Matched filtering in actionNow that you understand matched filtering, let's try it out with our fake data.

# %%
## Calculate the match with the detector data and just plain noise (no signal)MatchWithDetectorData = MatchedFiltering.Match(DetectorData, Signal, Noise)MatchWithPlainNoise = MatchedFiltering.Match(Noise, Signal, Noise)### Compare peak matchesprint("Largest match with detector data = {}".format(max(MatchWithDetectorData[50:-50])))print("Largest match with plain noise   = {}".format(max(MatchWithPlainNoise[50:-50])))print("Output signal-to-noise ratio = {}".format(max(MatchWithDetectorData[50:-50])                          /max(MatchWithPlainNoise[50:-50])))print("Input signal-to-noise ratio = {}".format(InputSignalToNoiseRatio))### Plot the resultsPlotEvery = 500;figure()semilogy(Noise.Time()[::PlotEvery], MatchWithDetectorData[::PlotEvery],          label="$\\mathrm{Match}(d,s)$");semilogy(Noise.Time()[::PlotEvery], MatchWithPlainNoise[::PlotEvery],          label="$\\mathrm{Match}(n,s)$");ylim(1e-5, 1e-1);xlabel("Time offset (seconds)");ylabel("Match");legend(loc="upper right");
# Out:
# Largest match with detector data = 0.00786795421027Largest match with plain noise   = 0.000640490825287
# Output signal-to-noise ratio = 12.2842574782
# Input signal-to-noise ratio = 0.01

# %% [markdown]
# This plot shows that if we search for the signal in pure noise, we get noise &mdash; a bunch of spikes, butnone really bigger than any other.  But if we search for the signal in our (faked) detector data, we see a big spike right around 1 second of time offset.  This is exactly the time offset we gave the injected signal.  Because this spike is so big, and comes just where we expect it to, we can say that we've detectedthe swept sine-Gaussian signal in noise that's 10,000 times louder than the signal!

# %% [markdown]
# ## Questions* We said that the match should be 1 if the data and signal are perfectly matched.  Why doesn't the spikein our plot go to 1?* Why is the spike in our plot wide?  Why isn't it just a single spike with exactly the offset we gave the signal?* For a real measurement, we don't have the pure noise, so we can't make the green line above.  All we would ever see is a spike in our data.  How can we decide if that spike is real or not?

# %% [markdown]
# <br /><br /><br /># Record real data and try to find the signal

# %%
NsM40 = MatchedFiltering.Waveform('Sounds/EqualMassNonspinning_Re_M040.wav')plot(NsM40.Time(), NsM40.data)

# %%
### Convert to frequency domainNsM40FFT = NsM40.dt * np.fft.fft(NsM40.data) # Take the Fourier transform and save as 'NoiseFFT'NsM40Frequencies = np.fft.fftfreq(NsM40.N, NsM40.dt) # Values of the f_i### Only plot some of the data, because python is slow at this jobPlotPoints = NsM40.N/2 # first half of the data (positive frequencies)#PlotEvery = 1 # every 500th point for speed### Now do the actual plotting:figure()loglog(NsM40Frequencies[:PlotPoints:PlotEvery], abs(NsM40FFT[:PlotPoints:PlotEvery]));#xlim(0,25000);xlim(40,4096);xlabel("$f_i$ (measured in Hertz)");ylabel("$\\tilde{n}_{f_i}$ (measured in arbitrary units)");title("Amplitude of the Fourier transform of NsM10");

# %%
# Load the templatesNonspinning5 = MatchedFiltering.Waveform('SoundCreation/EqualMassNonspinning_Re_M5.wav')

# %%
# Record the signalSignal = MatchedFiltering.RecordWaveform(15)
# Out:
# Recording...Done recording.

# %%
# Fake the signalRatio = 1e-3Signal = (1-Ratio)*Noise+Ratio*Nonspinning5

# %%
OverlapQuantityOfSignal = MatchedFiltering.Overlap(Signal, Nonspinning5, PSD)OverlapQuantityOfNoise = MatchedFiltering.Overlap(Noise, Nonspinning5, PSD)

# %%
PlotEvery = 500semilogy(Signal.Time()[::PlotEvery], OverlapQuantityOfSignal[::PlotEvery], 'g')semilogy(Signal.Time()[::PlotEvery], OverlapQuantityOfNoise[::PlotEvery], 'b')[max(OverlapQuantityOfSignal), max(OverlapQuantityOfNoise)]
# Out:
# [0.14706301738417621, 0.1118073478260185]

# %%
Signal.Play()

# %%
Nonspinning5.Play()

# %%
Noise.Play()
